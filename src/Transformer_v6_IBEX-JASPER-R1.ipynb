# %%
import os
import tifffile
import math
import numpy as np
from typing import Optional
import scipy.io as sio
import rasterio

import torch
import torch.nn as nn
import torch.nn.functional as F
#from pytorch_msssim import ssim
from torchvision.models import resnet101
from torch.utils.data import Dataset, DataLoader
from torchvision.models.feature_extraction import create_feature_extractor
import torch.distributed as dist
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data import DataLoader, DistributedSampler

#from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.manual_seed(42)
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
patches_folder='jasper'
file_prefix='jasperRidge2_R198'

initialization_path = 'Data/Input/jasper_vca.pt'

num_endmembers = 4

# %%
data = torch.load(initialization_path)

vca_spectra   = data['vca_spectra'].cuda()  # move to GPU if you like
gt_spectra    = data['gt_spectra'].cuda()
vca_spectra   = vca_spectra.permute(0,2,1)
gt_spectra    = gt_spectra.permute(0,2,1)
print("Loaded data")
print("VCA spectra shape:", vca_spectra.shape)
print("GT spectra shape: ", gt_spectra.shape)
# Out:
# Loaded data
# VCA spectra shape: torch.Size([1, 4, 198])
# GT spectra shape:  torch.Size([1, 4, 198])

# %%
def spectral_angle_loss(recon, target):
    # both [B, F, H, W] → flatten to [B, F, Npix]
    a = recon.view(recon.size(0), recon.size(1), -1)
    b = target.view(target.size(0), target.size(1), -1)
    # cosine similarity
    cs = (a * b).sum(dim=1) / (a.norm(dim=1) * b.norm(dim=1) + 1e-6)
    # angle in radians
    sam = torch.acos(cs.clamp(-1+1e-6, 1-1e-6))
    return sam.mean()

# %%
class HSIPatchDataset(Dataset):
    def __init__(self, patches_folder, file_prefix, num_endmembers, vca_tensor, gt_tensor, transform=None):
        """
        Dataset for loading preprocessed and normalized HSI patches with matching VCA/GT spectra.

        Parameters:
            patches_folder (str): Directory where the patch TIFF files are stored.
            file_prefix (str): Filename prefix for the patch files (e.g., "tile761_patch").
            highlight_info (list of tuples): Each tuple is (patch_number, num_endmembers).
            vca_tensor (torch.Tensor): [N, E, bands] per-patch VCA spectra.
            gt_tensor  (torch.Tensor): [N, E, bands] per-patch GT spectra.
            transform (callable, optional): Optional transform to be applied on a patch.
        """
        self.patches_folder = patches_folder
        self.file_prefix = file_prefix
        self.num_endmembers = num_endmembers 
        self.patch_number = 46 
        self.length = 1
        self.vca = vca_tensor.float()
        self.gt = gt_tensor.float()
        self.transform = transform

    def __len__(self):
        return self.length
        
    def __getitem__(self, idx):
        # Unpack the tuple: patch number and number of endmembers
        num_endmembers = self.num_endmembers
        patch_number = self.patch_number
        # Build file path and read TIFF
        filename = f"{self.file_prefix}.img"
        file_path = os.path.join(self.patches_folder, filename)
        with rasterio.open(file_path, driver='ENVI') as src:
            patch = src.read()   # shape: (bands, H, W)
        #patch = patch.transpose(2,0,1)
        # Convert to float32 Tensor
        patch_tensor = torch.from_numpy(patch.astype('float32'))  # [bands, H, W]
        
        # L2‐normalize each pixel's spectrum (across bands)
        flat = patch_tensor.view(patch_tensor.size(0), -1)  # [bands, H*W]
        flat = F.normalize(flat, p=2, dim=0, eps=1e-6)
        patch_tensor = flat.view_as(patch_tensor)          # back to [bands, H, W]
        
        # Optional transform (e.g., augmentations)
        if self.transform:
            patch_tensor = self.transform(patch_tensor)

        # Select and L2‐normalize VCA and GT spectra
        vca_spec = F.normalize(self.vca[idx], p=2, dim=-1, eps=1e-6)  # [E, bands]
        gt_spec  = F.normalize(self.gt[idx],  p=2, dim=-1, eps=1e-6)   # [E, bands]

        return {
            "patch": patch_tensor,              # Tensor: [bands, H, W]
            "vca":   vca_spec,                  # [E, bands]
            "gt":    gt_spec,                   # [E, bands]
            "patch_number": patch_number,       # int
            "num_endmembers": num_endmembers    # int
        }

# %%
class TransformerEncoderBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, mlp_dim, dropout=0.1):
        super().__init__()
        self.norm1 = nn.LayerNorm(embed_dim)
        self.attn = nn.MultiheadAttention(embed_dim, num_heads, dropout=dropout, batch_first=True)
        self.norm2 = nn.LayerNorm(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, mlp_dim),
            nn.GELU(),
            nn.Linear(mlp_dim, embed_dim)
        )

    def forward(self, x):
        # x: [B, tokens, embed_dim]
        x = x + self.attn(self.norm1(x), self.norm1(x), self.norm1(x))[0]
        x = x + self.mlp(self.norm2(x))
        return x


class HSITransformer(nn.Module):
    def __init__(self,
                 bands,
                 embed_dim,
                 num_heads,
                 mlp_dim,
                 num_layers,
                 num_endmembers,
                 patch_size=1,
                 token_mode="full"):
        super().__init__()
        self.patch_size = patch_size
        self.token_mode = token_mode

        num_patches_side = 100 // patch_size
        self.num_patches = num_patches_side ** 2

        self.patch_embed = nn.Conv2d(
            in_channels=bands,
            out_channels=embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.vca_conv = nn.Conv1d(
            in_channels=bands,
            out_channels=embed_dim,
            kernel_size=1
        )
        self.gt_conv = nn.Conv1d(
            in_channels=bands,
            out_channels=embed_dim,
            kernel_size=1
        )

        if self.token_mode == "full":
            self.num_special_tokens = 3
        elif self.token_mode in ["no_cl", "no_vca"]:
            self.num_special_tokens = 2
        elif self.token_mode == "cls_only":
            self.num_special_tokens = 1
        else:
            raise ValueError(f"Unknown token_mode: {self.token_mode}")

        total_tokens = self.num_special_tokens + self.num_patches
        self.pos_embed = nn.Parameter(torch.zeros(1, total_tokens, embed_dim))

        self.encoder = nn.Sequential(*[
            TransformerEncoderBlock(embed_dim, num_heads, mlp_dim)
            for _ in range(num_layers)
        ])

        # changed decoder head
        self.head = nn.Conv2d(
            embed_dim,
            num_endmembers * patch_size * patch_size,
            kernel_size=1
        )
        self.pixel_shuffle = nn.PixelShuffle(patch_size)

    def forward(self, x, vca_init, gt_init, return_full=False):
        B = x.size(0)

        patches = self.patch_embed(x)
        tokens_local = patches.flatten(2).transpose(1, 2)

        cls_tokens = self.cls_token.expand(B, -1, -1)
        token_list = [cls_tokens]

        if self.token_mode in ["full", "no_cl"]:
            vca_emb = self.vca_conv(vca_init.permute(0, 2, 1))
            vca_tok = vca_emb.mean(dim=2, keepdim=True).transpose(1, 2)
            token_list.append(vca_tok)

        if self.token_mode in ["full", "no_vca"]:
            gt_emb = self.gt_conv(gt_init.permute(0, 2, 1))
            gt_tok = gt_emb.mean(dim=2, keepdim=True).transpose(1, 2)
            token_list.append(gt_tok)

        token_list.append(tokens_local)
        tokens = torch.cat(token_list, dim=1)

        tokens = tokens + self.pos_embed
        encoded = self.encoder(tokens)

        patch_tokens = encoded[:, self.num_special_tokens:, :]

        Hp = Wp = 100 // self.patch_size
        feat = patch_tokens.transpose(1, 2).view(
            B, self.patch_embed.out_channels, Hp, Wp
        )

        ab_logits = self.head(feat)            # [B, E*P*P, Hp, Wp]
        ab_map = self.pixel_shuffle(ab_logits) # [B, E, H, W]
        ab_map = F.softmax(ab_map, dim=1)

        return ab_map

    def _reconstruct_with_fold(self, ab_patch):
            B, C, P_h, P_w = ab_patch.shape
            num_patches    = P_h * P_w
            patch_area     = self.patch_size * self.patch_size
    
            # Flatten to (B, C, L)
            patches = ab_patch.view(B, C, num_patches)
    
            # Expand each patch element into patch_area
            patches = patches.unsqueeze(-1).expand(-1, -1, -1, patch_area)
            patches = patches.reshape(B, C * patch_area, num_patches)
    
            # Fold back to (B, C, 256, 256)
            full_map = self.fold(patches)
            return full_map

# %%
# 0) Early stopping params
patience           = 1000              # quante epoche di plateau prima di fermarsi
best_loss          = float('inf')     # inizialmente infinito
epochs_without_improvement = 0

# 1) Hyperparameters
lr          = 1e-3
num_epochs  = 1000
batch_size  = 1

# 2) Model, optimizer, loss
# model       = HSITransformer(
#     bands=198, embed_dim=64,
#     num_heads=2, mlp_dim=128, num_layers=4,
#     num_endmembers=num_endmembers,
#     patch_size=1
# )
TOKEN_MODE = "full"   # choose from: "full", "no_cl", "no_vca", "cls_only"
PATCH_SIZE = 4        # run later also with 2 and 4

model = HSITransformer(
    bands=198,
    embed_dim=64,
    num_heads=2,
    mlp_dim=128,
    num_layers=4,
    num_endmembers=num_endmembers,
    patch_size=PATCH_SIZE,
    token_mode=TOKEN_MODE
)
pos_init = model.pos_embed.detach().cpu().clone().numpy()[0] 

# 2) If you have more than 1 GPU, wrap in DataParallel
if torch.cuda.device_count() > 1:
    print(f"Detected {torch.cuda.device_count()} GPUs. Using DataParallel.")
    model = nn.DataParallel(model, device_ids=[0,1,2])

model = model.to(device)

optimizer   = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
               mode='min', factor=0.1, patience=50, min_lr=1e-5)
criterion   = nn.MSELoss()


# right after you load/model-init your vca/gt
vca_spectra_cpu = vca_spectra.detach().cpu()
gt_spectra_cpu = gt_spectra.detach().cpu()

# 3) DataLoader (reuse your HSIPatchDataset)
dataset     = HSIPatchDataset(
    patches_folder=patches_folder,
    file_prefix=file_prefix,
    num_endmembers=4,
    vca_tensor=vca_spectra_cpu,    # [N, E, bands]
    gt_tensor=gt_spectra_cpu       # [N, E, bands]
)
dataloader  = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %%
# 4) Training loop
loss_history = []

for epoch in range(1, num_epochs+1):
    model.train()
    running_loss = 0.0

    for batch in dataloader:
        x      = batch['patch'].to(device, non_blocking=True)   # [B, bands, H, W]
        vca    = batch['vca'].to(device, non_blocking=True)     # [B, E, bands]
        gt     = batch['gt'].to(device, non_blocking=True)      # [B, E, bands]

        optimizer.zero_grad()

        # forward pass → abundance maps [B, E, H, W]
        #abundances = model(x, vca, gt)
        abundances = model(x, vca, gt, return_full=True)

        # reconstruct the patch: R[b,f,i,j] = sum_e abundances[b,e,i,j] * vca[b,e,f]
        # Using einsum for clarity:
        reconstruction = torch.einsum('behw,bef->bfhw', abundances, vca)
        
        # # 1) Upsample a 256×256
        # reconstruction= F.interpolate(
        #     reconstruction,
        #     size=(x.shape[2], x.shape[3]),    # (256,256)
        #     mode='bilinear',
        #     align_corners=False
        # )
        
        # compute MSE loss between original and reconstruction
        # in training:
        loss_mse = criterion(reconstruction, x)
        loss_sam = spectral_angle_loss(reconstruction, x)
        loss = 0.1*loss_mse + 0.1 * loss_sam
        #loss = criterion(reconstruction, x)

        loss.backward()
        
        optimizer.step()

        running_loss += loss.item() * x.size(0)

    epoch_loss = running_loss / len(dataset)
    loss_history.append(epoch_loss)
    print(f"Epoch {epoch}/{num_epochs} — Loss: {epoch_loss:.6f}")
    scheduler.step(epoch_loss)

    # --- Early stopping check ---
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        epochs_without_improvement = 0
        # (opzionale) salva il modello migliore
        #torch.save(model.state_dict(), "best_model.pth")
    else:
        epochs_without_improvement += 1
        print(f"  ↳ nessun miglioramento per {epochs_without_improvement}/{patience} epoche")

    if epochs_without_improvement >= patience:
        print(f"Early stopping dopo {epoch} epoche (pazienza esaurita).")
        break

print("Training complete.")
# Out:
# /home/scillad/miniconda3/envs/unmixing/lib/python3.10/site-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Epoch 1/1000 — Loss: 0.047399
# Epoch 2/1000 — Loss: 0.047372
# Epoch 3/1000 — Loss: 0.045250
# Epoch 4/1000 — Loss: 0.044848
# Epoch 5/1000 — Loss: 0.044456
# Epoch 6/1000 — Loss: 0.043844
# Epoch 7/1000 — Loss: 0.043200
# Epoch 8/1000 — Loss: 0.042489
# Epoch 9/1000 — Loss: 0.041492
# Epoch 10/1000 — Loss: 0.040084
# Epoch 11/1000 — Loss: 0.038109
# Epoch 12/1000 — Loss: 0.035272
# Epoch 13/1000 — Loss: 0.031711
# Epoch 14/1000 — Loss: 0.028213
# Epoch 15/1000 — Loss: 0.025579
# Epoch 16/1000 — Loss: 0.023772
# Epoch 17/1000 — Loss: 0.022152
# Epoch 18/1000 — Loss: 0.020679
# Epoch 19/1000 — Loss: 0.019560
# Epoch 20/1000 — Loss: 0.018763
# Epoch 21/1000 — Loss: 0.018073
# Epoch 22/1000 — Loss: 0.017418
# Epoch 23/1000 — Loss: 0.016812
# Epoch 24/1000 — Loss: 0.016285
# Epoch 25/1000 — Loss: 0.015864
# Epoch 26/1000 — Loss: 0.015570
# Epoch 27/1000 — Loss: 0.015149
# Epoch 28/1000 — Loss: 0.014980
# Epoch 29/1000 — Loss: 0.015026
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 30/1000 — Loss: 0.014941
# Epoch 31/1000 — Loss: 0.014852
# Epoch 32/1000 — Loss: 0.014741
# Epoch 33/1000 — Loss: 0.014660
# Epoch 34/1000 — Loss: 0.014485
# Epoch 35/1000 — Loss: 0.014365
# Epoch 36/1000 — Loss: 0.014350
# Epoch 37/1000 — Loss: 0.014228
# Epoch 38/1000 — Loss: 0.014097
# Epoch 39/1000 — Loss: 0.014048
# Epoch 40/1000 — Loss: 0.014021
# Epoch 41/1000 — Loss: 0.013958
# Epoch 42/1000 — Loss: 0.013917
# Epoch 43/1000 — Loss: 0.013901
# Epoch 44/1000 — Loss: 0.013806
# Epoch 45/1000 — Loss: 0.013737
# Epoch 46/1000 — Loss: 0.013690
# Epoch 47/1000 — Loss: 0.013615
# Epoch 48/1000 — Loss: 0.013565
# Epoch 49/1000 — Loss: 0.013533
# Epoch 50/1000 — Loss: 0.013488
# Epoch 51/1000 — Loss: 0.013465
# Epoch 52/1000 — Loss: 0.013429
# Epoch 53/1000 — Loss: 0.013375
# Epoch 54/1000 — Loss: 0.013328
# Epoch 55/1000 — Loss: 0.013286
# Epoch 56/1000 — Loss: 0.013256
# Epoch 57/1000 — Loss: 0.013202
# Epoch 58/1000 — Loss: 0.013164
# Epoch 59/1000 — Loss: 0.013137
# Epoch 60/1000 — Loss: 0.013113
# Epoch 61/1000 — Loss: 0.013084
# Epoch 62/1000 — Loss: 0.013045
# Epoch 63/1000 — Loss: 0.013011
# Epoch 64/1000 — Loss: 0.012982
# Epoch 65/1000 — Loss: 0.012947
# Epoch 66/1000 — Loss: 0.012929
# Epoch 67/1000 — Loss: 0.012898
# Epoch 68/1000 — Loss: 0.012868
# Epoch 69/1000 — Loss: 0.012837
# Epoch 70/1000 — Loss: 0.012789
# Epoch 71/1000 — Loss: 0.012747
# Epoch 72/1000 — Loss: 0.012720
# Epoch 73/1000 — Loss: 0.012681
# Epoch 74/1000 — Loss: 0.012655
# Epoch 75/1000 — Loss: 0.012617
# Epoch 76/1000 — Loss: 0.012585
# Epoch 77/1000 — Loss: 0.012560
# Epoch 78/1000 — Loss: 0.012549
# Epoch 79/1000 — Loss: 0.012528
# Epoch 80/1000 — Loss: 0.012498
# Epoch 81/1000 — Loss: 0.012428
# Epoch 82/1000 — Loss: 0.012338
# Epoch 83/1000 — Loss: 0.012262
# Epoch 84/1000 — Loss: 0.012212
# Epoch 85/1000 — Loss: 0.012182
# Epoch 86/1000 — Loss: 0.012177
# Epoch 87/1000 — Loss: 0.012172
# Epoch 88/1000 — Loss: 0.012149
# Epoch 89/1000 — Loss: 0.012066
# Epoch 90/1000 — Loss: 0.011954
# Epoch 91/1000 — Loss: 0.011843
# Epoch 92/1000 — Loss: 0.011765
# Epoch 93/1000 — Loss: 0.011715
# Epoch 94/1000 — Loss: 0.011711
# Epoch 95/1000 — Loss: 0.011718
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 96/1000 — Loss: 0.011713
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 97/1000 — Loss: 0.011613
# Epoch 98/1000 — Loss: 0.011444
# Epoch 99/1000 — Loss: 0.011326
# Epoch 100/1000 — Loss: 0.011296
# Epoch 101/1000 — Loss: 0.011333
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 102/1000 — Loss: 0.011359
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 103/1000 — Loss: 0.011236
# Epoch 104/1000 — Loss: 0.011085
# Epoch 105/1000 — Loss: 0.011009
# Epoch 106/1000 — Loss: 0.011029
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 107/1000 — Loss: 0.011179
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 108/1000 — Loss: 0.011152
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 109/1000 — Loss: 0.010976
# Epoch 110/1000 — Loss: 0.010859
# Epoch 111/1000 — Loss: 0.010834
# Epoch 112/1000 — Loss: 0.010826
# Epoch 113/1000 — Loss: 0.010813
# Epoch 114/1000 — Loss: 0.010759
# Epoch 115/1000 — Loss: 0.010676
# Epoch 116/1000 — Loss: 0.010760
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 117/1000 — Loss: 0.010804
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 118/1000 — Loss: 0.010791
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 119/1000 — Loss: 0.010652
# Epoch 120/1000 — Loss: 0.010566
# Epoch 121/1000 — Loss: 0.010458
# Epoch 122/1000 — Loss: 0.010485
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 123/1000 — Loss: 0.010584
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 124/1000 — Loss: 0.010448
# Epoch 125/1000 — Loss: 0.010356
# Epoch 126/1000 — Loss: 0.010487
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 127/1000 — Loss: 0.010392
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 128/1000 — Loss: 0.010216
# Epoch 129/1000 — Loss: 0.010324
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 130/1000 — Loss: 0.010239
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 131/1000 — Loss: 0.010155
# Epoch 132/1000 — Loss: 0.010198
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 133/1000 — Loss: 0.010136
# Epoch 134/1000 — Loss: 0.010100
# Epoch 135/1000 — Loss: 0.010070
# Epoch 136/1000 — Loss: 0.010081
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 137/1000 — Loss: 0.010002
# Epoch 138/1000 — Loss: 0.009980
# Epoch 139/1000 — Loss: 0.009991
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 140/1000 — Loss: 0.009929
# Epoch 141/1000 — Loss: 0.009947
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 142/1000 — Loss: 0.009931
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 143/1000 — Loss: 0.009933
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 144/1000 — Loss: 0.009966
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 145/1000 — Loss: 0.009942
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 146/1000 — Loss: 0.009889
# Epoch 147/1000 — Loss: 0.009817
# Epoch 148/1000 — Loss: 0.009763
# Epoch 149/1000 — Loss: 0.009755
# Epoch 150/1000 — Loss: 0.009751
# Epoch 151/1000 — Loss: 0.009770
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 152/1000 — Loss: 0.009789
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 153/1000 — Loss: 0.009766
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 154/1000 — Loss: 0.009697
# Epoch 155/1000 — Loss: 0.009658
# Epoch 156/1000 — Loss: 0.009637
# Epoch 157/1000 — Loss: 0.009610
# Epoch 158/1000 — Loss: 0.009609
# Epoch 159/1000 — Loss: 0.009648
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 160/1000 — Loss: 0.009641
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 161/1000 — Loss: 0.009603
# Epoch 162/1000 — Loss: 0.009588
# Epoch 163/1000 — Loss: 0.009501
# Epoch 164/1000 — Loss: 0.009457
# Epoch 165/1000 — Loss: 0.009513
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 166/1000 — Loss: 0.009532
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 167/1000 — Loss: 0.009518
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 168/1000 — Loss: 0.009529
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 169/1000 — Loss: 0.009455
# Epoch 170/1000 — Loss: 0.009406
# Epoch 171/1000 — Loss: 0.009387
# Epoch 172/1000 — Loss: 0.009360
# Epoch 173/1000 — Loss: 0.009328
# Epoch 174/1000 — Loss: 0.009336
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 175/1000 — Loss: 0.009339
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 176/1000 — Loss: 0.009279
# Epoch 177/1000 — Loss: 0.009248
# Epoch 178/1000 — Loss: 0.009280
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 179/1000 — Loss: 0.009400
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 180/1000 — Loss: 0.009406
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 181/1000 — Loss: 0.009349
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 182/1000 — Loss: 0.009290
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 183/1000 — Loss: 0.009232
# Epoch 184/1000 — Loss: 0.009208
# Epoch 185/1000 — Loss: 0.009178
# Epoch 186/1000 — Loss: 0.009163
# Epoch 187/1000 — Loss: 0.009167
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 188/1000 — Loss: 0.009162
# Epoch 189/1000 — Loss: 0.009136
# Epoch 190/1000 — Loss: 0.009105
# Epoch 191/1000 — Loss: 0.009098
# Epoch 192/1000 — Loss: 0.009114
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 193/1000 — Loss: 0.009087
# Epoch 194/1000 — Loss: 0.009025
# Epoch 195/1000 — Loss: 0.009015
# Epoch 196/1000 — Loss: 0.009041
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 197/1000 — Loss: 0.009032
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 198/1000 — Loss: 0.009014
# Epoch 199/1000 — Loss: 0.009043
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 200/1000 — Loss: 0.009092
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 201/1000 — Loss: 0.009101
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 202/1000 — Loss: 0.009012
# Epoch 203/1000 — Loss: 0.008958
# Epoch 204/1000 — Loss: 0.008975
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 205/1000 — Loss: 0.008993
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 206/1000 — Loss: 0.008986
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 207/1000 — Loss: 0.009024
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 208/1000 — Loss: 0.009008
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 209/1000 — Loss: 0.008935
# Epoch 210/1000 — Loss: 0.008900
# Epoch 211/1000 — Loss: 0.008890
# Epoch 212/1000 — Loss: 0.008888
# Epoch 213/1000 — Loss: 0.008932
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 214/1000 — Loss: 0.008998
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 215/1000 — Loss: 0.008988
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 216/1000 — Loss: 0.008901
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 217/1000 — Loss: 0.008851
# Epoch 218/1000 — Loss: 0.008838
# Epoch 219/1000 — Loss: 0.008799
# Epoch 220/1000 — Loss: 0.008817
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 221/1000 — Loss: 0.008849
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 222/1000 — Loss: 0.008828
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 223/1000 — Loss: 0.008782
# Epoch 224/1000 — Loss: 0.008769
# Epoch 225/1000 — Loss: 0.008765
# Epoch 226/1000 — Loss: 0.008760
# Epoch 227/1000 — Loss: 0.008748
# Epoch 228/1000 — Loss: 0.008751
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 229/1000 — Loss: 0.008773
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 230/1000 — Loss: 0.008770
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 231/1000 — Loss: 0.008757
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 232/1000 — Loss: 0.008723
# Epoch 233/1000 — Loss: 0.008704
# Epoch 234/1000 — Loss: 0.008691
# Epoch 235/1000 — Loss: 0.008677
# Epoch 236/1000 — Loss: 0.008669
# Epoch 237/1000 — Loss: 0.008689
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 238/1000 — Loss: 0.008720
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 239/1000 — Loss: 0.008718
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 240/1000 — Loss: 0.008669
# Epoch 241/1000 — Loss: 0.008614
# Epoch 242/1000 — Loss: 0.008588
# Epoch 243/1000 — Loss: 0.008599
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 244/1000 — Loss: 0.008615
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 245/1000 — Loss: 0.008619
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 246/1000 — Loss: 0.008609
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 247/1000 — Loss: 0.008595
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 248/1000 — Loss: 0.008588
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 249/1000 — Loss: 0.008563
# Epoch 250/1000 — Loss: 0.008551
# Epoch 251/1000 — Loss: 0.008552
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 252/1000 — Loss: 0.008548
# Epoch 253/1000 — Loss: 0.008554
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 254/1000 — Loss: 0.008559
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 255/1000 — Loss: 0.008578
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 256/1000 — Loss: 0.008604
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 257/1000 — Loss: 0.008644
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 258/1000 — Loss: 0.008627
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 259/1000 — Loss: 0.008559
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 260/1000 — Loss: 0.008528
# Epoch 261/1000 — Loss: 0.008513
# Epoch 262/1000 — Loss: 0.008504
# Epoch 263/1000 — Loss: 0.008494
# Epoch 264/1000 — Loss: 0.008511
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 265/1000 — Loss: 0.008523
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 266/1000 — Loss: 0.008504
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 267/1000 — Loss: 0.008504
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 268/1000 — Loss: 0.008611
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 269/1000 — Loss: 0.008622
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 270/1000 — Loss: 0.008544
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 271/1000 — Loss: 0.008487
# Epoch 272/1000 — Loss: 0.008478
# Epoch 273/1000 — Loss: 0.008487
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 274/1000 — Loss: 0.008444
# Epoch 275/1000 — Loss: 0.008473
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 276/1000 — Loss: 0.008467
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 277/1000 — Loss: 0.008429
# Epoch 278/1000 — Loss: 0.008454
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 279/1000 — Loss: 0.008416
# Epoch 280/1000 — Loss: 0.008372
# Epoch 281/1000 — Loss: 0.008392
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 282/1000 — Loss: 0.008399
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 283/1000 — Loss: 0.008392
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 284/1000 — Loss: 0.008401
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 285/1000 — Loss: 0.008435
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 286/1000 — Loss: 0.008432
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 287/1000 — Loss: 0.008441
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 288/1000 — Loss: 0.008391
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 289/1000 — Loss: 0.008356
# Epoch 290/1000 — Loss: 0.008375
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 291/1000 — Loss: 0.008359
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 292/1000 — Loss: 0.008344
# Epoch 293/1000 — Loss: 0.008330
# Epoch 294/1000 — Loss: 0.008324
# Epoch 295/1000 — Loss: 0.008351
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 296/1000 — Loss: 0.008415
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 297/1000 — Loss: 0.008422
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 298/1000 — Loss: 0.008425
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 299/1000 — Loss: 0.008375
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 300/1000 — Loss: 0.008360
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 301/1000 — Loss: 0.008309
# Epoch 302/1000 — Loss: 0.008289
# Epoch 303/1000 — Loss: 0.008295
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 304/1000 — Loss: 0.008314
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 305/1000 — Loss: 0.008300
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 306/1000 — Loss: 0.008296
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 307/1000 — Loss: 0.008300
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 308/1000 — Loss: 0.008302
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 309/1000 — Loss: 0.008299
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 310/1000 — Loss: 0.008304
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 311/1000 — Loss: 0.008291
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 312/1000 — Loss: 0.008257
# Epoch 313/1000 — Loss: 0.008241
# Epoch 314/1000 — Loss: 0.008242
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 315/1000 — Loss: 0.008251
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 316/1000 — Loss: 0.008283
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 317/1000 — Loss: 0.008323
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 318/1000 — Loss: 0.008347
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 319/1000 — Loss: 0.008392
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 320/1000 — Loss: 0.008318
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 321/1000 — Loss: 0.008284
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 322/1000 — Loss: 0.008264
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 323/1000 — Loss: 0.008244
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 324/1000 — Loss: 0.008252
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 325/1000 — Loss: 0.008286
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 326/1000 — Loss: 0.008285
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 327/1000 — Loss: 0.008242
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 328/1000 — Loss: 0.008237
# Epoch 329/1000 — Loss: 0.008261
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 330/1000 — Loss: 0.008232
# Epoch 331/1000 — Loss: 0.008230
# Epoch 332/1000 — Loss: 0.008213
# Epoch 333/1000 — Loss: 0.008204
# Epoch 334/1000 — Loss: 0.008197
# Epoch 335/1000 — Loss: 0.008213
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 336/1000 — Loss: 0.008220
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 337/1000 — Loss: 0.008188
# Epoch 338/1000 — Loss: 0.008174
# Epoch 339/1000 — Loss: 0.008172
# Epoch 340/1000 — Loss: 0.008180
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 341/1000 — Loss: 0.008191
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 342/1000 — Loss: 0.008163
# Epoch 343/1000 — Loss: 0.008150
# Epoch 344/1000 — Loss: 0.008174
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 345/1000 — Loss: 0.008187
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 346/1000 — Loss: 0.008177
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 347/1000 — Loss: 0.008146
# Epoch 348/1000 — Loss: 0.008137
# Epoch 349/1000 — Loss: 0.008137
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 350/1000 — Loss: 0.008134
# Epoch 351/1000 — Loss: 0.008133
# Epoch 352/1000 — Loss: 0.008130
# Epoch 353/1000 — Loss: 0.008123
# Epoch 354/1000 — Loss: 0.008108
# Epoch 355/1000 — Loss: 0.008111
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 356/1000 — Loss: 0.008121
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 357/1000 — Loss: 0.008118
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 358/1000 — Loss: 0.008095
# Epoch 359/1000 — Loss: 0.008076
# Epoch 360/1000 — Loss: 0.008074
# Epoch 361/1000 — Loss: 0.008083
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 362/1000 — Loss: 0.008090
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 363/1000 — Loss: 0.008095
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 364/1000 — Loss: 0.008116
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 365/1000 — Loss: 0.008125
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 366/1000 — Loss: 0.008122
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 367/1000 — Loss: 0.008090
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 368/1000 — Loss: 0.008082
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 369/1000 — Loss: 0.008080
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 370/1000 — Loss: 0.008084
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 371/1000 — Loss: 0.008083
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 372/1000 — Loss: 0.008093
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 373/1000 — Loss: 0.008120
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 374/1000 — Loss: 0.008132
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 375/1000 — Loss: 0.008145
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 376/1000 — Loss: 0.008136
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 377/1000 — Loss: 0.008180
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 378/1000 — Loss: 0.008193
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 379/1000 — Loss: 0.008136
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 380/1000 — Loss: 0.008075
#   ↳ nessun miglioramento per 20/1000 epoche
# Epoch 381/1000 — Loss: 0.008055
# Epoch 382/1000 — Loss: 0.008092
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 383/1000 — Loss: 0.008112
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 384/1000 — Loss: 0.008100
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 385/1000 — Loss: 0.008067
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 386/1000 — Loss: 0.008061
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 387/1000 — Loss: 0.008082
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 388/1000 — Loss: 0.008073
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 389/1000 — Loss: 0.008060
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 390/1000 — Loss: 0.008045
# Epoch 391/1000 — Loss: 0.008045
# Epoch 392/1000 — Loss: 0.008040
# Epoch 393/1000 — Loss: 0.008038
# Epoch 394/1000 — Loss: 0.008054
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 395/1000 — Loss: 0.008053
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 396/1000 — Loss: 0.008021
# Epoch 397/1000 — Loss: 0.008015
# Epoch 398/1000 — Loss: 0.008024
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 399/1000 — Loss: 0.008009
# Epoch 400/1000 — Loss: 0.008004
# Epoch 401/1000 — Loss: 0.008016
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 402/1000 — Loss: 0.008016
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 403/1000 — Loss: 0.008004
# Epoch 404/1000 — Loss: 0.008002
# Epoch 405/1000 — Loss: 0.008013
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 406/1000 — Loss: 0.008017
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 407/1000 — Loss: 0.008014
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 408/1000 — Loss: 0.008011
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 409/1000 — Loss: 0.008008
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 410/1000 — Loss: 0.007987
# Epoch 411/1000 — Loss: 0.007973
# Epoch 412/1000 — Loss: 0.007965
# Epoch 413/1000 — Loss: 0.007964
# Epoch 414/1000 — Loss: 0.007962
# Epoch 415/1000 — Loss: 0.007968
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 416/1000 — Loss: 0.007982
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 417/1000 — Loss: 0.008002
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 418/1000 — Loss: 0.008006
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 419/1000 — Loss: 0.008022
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 420/1000 — Loss: 0.008012
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 421/1000 — Loss: 0.008008
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 422/1000 — Loss: 0.007994
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 423/1000 — Loss: 0.007988
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 424/1000 — Loss: 0.007985
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 425/1000 — Loss: 0.007979
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 426/1000 — Loss: 0.007981
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 427/1000 — Loss: 0.007992
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 428/1000 — Loss: 0.007996
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 429/1000 — Loss: 0.007966
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 430/1000 — Loss: 0.007942
# Epoch 431/1000 — Loss: 0.007939
# Epoch 432/1000 — Loss: 0.007955
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 433/1000 — Loss: 0.007972
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 434/1000 — Loss: 0.007960
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 435/1000 — Loss: 0.007952
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 436/1000 — Loss: 0.007960
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 437/1000 — Loss: 0.007981
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 438/1000 — Loss: 0.007998
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 439/1000 — Loss: 0.007980
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 440/1000 — Loss: 0.007973
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 441/1000 — Loss: 0.007951
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 442/1000 — Loss: 0.007948
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 443/1000 — Loss: 0.007938
# Epoch 444/1000 — Loss: 0.007930
# Epoch 445/1000 — Loss: 0.007937
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 446/1000 — Loss: 0.007931
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 447/1000 — Loss: 0.007918
# Epoch 448/1000 — Loss: 0.007908
# Epoch 449/1000 — Loss: 0.007907
# Epoch 450/1000 — Loss: 0.007913
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 451/1000 — Loss: 0.007929
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 452/1000 — Loss: 0.007949
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 453/1000 — Loss: 0.007938
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 454/1000 — Loss: 0.007925
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 455/1000 — Loss: 0.007915
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 456/1000 — Loss: 0.007907
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 457/1000 — Loss: 0.007909
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 458/1000 — Loss: 0.007931
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 459/1000 — Loss: 0.007964
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 460/1000 — Loss: 0.007976
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 461/1000 — Loss: 0.007960
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 462/1000 — Loss: 0.007932
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 463/1000 — Loss: 0.007911
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 464/1000 — Loss: 0.007920
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 465/1000 — Loss: 0.007923
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 466/1000 — Loss: 0.007903
# Epoch 467/1000 — Loss: 0.007892
# Epoch 468/1000 — Loss: 0.007908
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 469/1000 — Loss: 0.007940
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 470/1000 — Loss: 0.007983
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 471/1000 — Loss: 0.008003
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 472/1000 — Loss: 0.007960
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 473/1000 — Loss: 0.007903
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 474/1000 — Loss: 0.007894
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 475/1000 — Loss: 0.007904
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 476/1000 — Loss: 0.007918
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 477/1000 — Loss: 0.007908
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 478/1000 — Loss: 0.007908
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 479/1000 — Loss: 0.007925
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 480/1000 — Loss: 0.007927
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 481/1000 — Loss: 0.007931
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 482/1000 — Loss: 0.007929
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 483/1000 — Loss: 0.007908
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 484/1000 — Loss: 0.007896
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 485/1000 — Loss: 0.007896
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 486/1000 — Loss: 0.007895
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 487/1000 — Loss: 0.007889
# Epoch 488/1000 — Loss: 0.007881
# Epoch 489/1000 — Loss: 0.007879
# Epoch 490/1000 — Loss: 0.007890
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 491/1000 — Loss: 0.007891
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 492/1000 — Loss: 0.007887
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 493/1000 — Loss: 0.007878
# Epoch 494/1000 — Loss: 0.007872
# Epoch 495/1000 — Loss: 0.007861
# Epoch 496/1000 — Loss: 0.007854
# Epoch 497/1000 — Loss: 0.007858
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 498/1000 — Loss: 0.007859
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 499/1000 — Loss: 0.007854
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 500/1000 — Loss: 0.007844
# Epoch 501/1000 — Loss: 0.007836
# Epoch 502/1000 — Loss: 0.007830
# Epoch 503/1000 — Loss: 0.007835
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 504/1000 — Loss: 0.007848
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 505/1000 — Loss: 0.007856
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 506/1000 — Loss: 0.007856
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 507/1000 — Loss: 0.007864
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 508/1000 — Loss: 0.007884
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 509/1000 — Loss: 0.007911
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 510/1000 — Loss: 0.007890
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 511/1000 — Loss: 0.007877
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 512/1000 — Loss: 0.007834
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 513/1000 — Loss: 0.007819
# Epoch 514/1000 — Loss: 0.007823
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 515/1000 — Loss: 0.007836
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 516/1000 — Loss: 0.007857
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 517/1000 — Loss: 0.007866
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 518/1000 — Loss: 0.007865
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 519/1000 — Loss: 0.007846
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 520/1000 — Loss: 0.007842
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 521/1000 — Loss: 0.007844
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 522/1000 — Loss: 0.007848
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 523/1000 — Loss: 0.007855
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 524/1000 — Loss: 0.007847
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 525/1000 — Loss: 0.007828
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 526/1000 — Loss: 0.007811
# Epoch 527/1000 — Loss: 0.007807
# Epoch 528/1000 — Loss: 0.007810
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 529/1000 — Loss: 0.007804
# Epoch 530/1000 — Loss: 0.007803
# Epoch 531/1000 — Loss: 0.007809
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 532/1000 — Loss: 0.007811
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 533/1000 — Loss: 0.007810
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 534/1000 — Loss: 0.007804
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 535/1000 — Loss: 0.007811
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 536/1000 — Loss: 0.007817
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 537/1000 — Loss: 0.007824
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 538/1000 — Loss: 0.007833
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 539/1000 — Loss: 0.007839
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 540/1000 — Loss: 0.007843
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 541/1000 — Loss: 0.007840
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 542/1000 — Loss: 0.007820
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 543/1000 — Loss: 0.007810
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 544/1000 — Loss: 0.007806
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 545/1000 — Loss: 0.007808
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 546/1000 — Loss: 0.007813
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 547/1000 — Loss: 0.007810
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 548/1000 — Loss: 0.007808
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 549/1000 — Loss: 0.007802
# Epoch 550/1000 — Loss: 0.007793
# Epoch 551/1000 — Loss: 0.007784
# Epoch 552/1000 — Loss: 0.007780
# Epoch 553/1000 — Loss: 0.007779
# Epoch 554/1000 — Loss: 0.007781
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 555/1000 — Loss: 0.007782
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 556/1000 — Loss: 0.007790
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 557/1000 — Loss: 0.007800
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 558/1000 — Loss: 0.007812
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 559/1000 — Loss: 0.007823
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 560/1000 — Loss: 0.007820
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 561/1000 — Loss: 0.007811
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 562/1000 — Loss: 0.007798
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 563/1000 — Loss: 0.007796
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 564/1000 — Loss: 0.007802
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 565/1000 — Loss: 0.007793
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 566/1000 — Loss: 0.007790
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 567/1000 — Loss: 0.007790
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 568/1000 — Loss: 0.007799
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 569/1000 — Loss: 0.007785
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 570/1000 — Loss: 0.007772
# Epoch 571/1000 — Loss: 0.007759
# Epoch 572/1000 — Loss: 0.007757
# Epoch 573/1000 — Loss: 0.007763
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 574/1000 — Loss: 0.007767
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 575/1000 — Loss: 0.007770
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 576/1000 — Loss: 0.007768
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 577/1000 — Loss: 0.007766
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 578/1000 — Loss: 0.007771
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 579/1000 — Loss: 0.007792
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 580/1000 — Loss: 0.007815
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 581/1000 — Loss: 0.007809
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 582/1000 — Loss: 0.007792
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 583/1000 — Loss: 0.007772
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 584/1000 — Loss: 0.007761
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 585/1000 — Loss: 0.007759
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 586/1000 — Loss: 0.007767
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 587/1000 — Loss: 0.007783
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 588/1000 — Loss: 0.007791
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 589/1000 — Loss: 0.007804
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 590/1000 — Loss: 0.007821
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 591/1000 — Loss: 0.007818
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 592/1000 — Loss: 0.007809
#   ↳ nessun miglioramento per 20/1000 epoche
# Epoch 593/1000 — Loss: 0.007812
#   ↳ nessun miglioramento per 21/1000 epoche
# Epoch 594/1000 — Loss: 0.007765
#   ↳ nessun miglioramento per 22/1000 epoche
# Epoch 595/1000 — Loss: 0.007745
# Epoch 596/1000 — Loss: 0.007766
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 597/1000 — Loss: 0.007790
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 598/1000 — Loss: 0.007818
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 599/1000 — Loss: 0.007802
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 600/1000 — Loss: 0.007814
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 601/1000 — Loss: 0.007798
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 602/1000 — Loss: 0.007776
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 603/1000 — Loss: 0.007771
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 604/1000 — Loss: 0.007786
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 605/1000 — Loss: 0.007781
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 606/1000 — Loss: 0.007748
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 607/1000 — Loss: 0.007748
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 608/1000 — Loss: 0.007762
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 609/1000 — Loss: 0.007741
# Epoch 610/1000 — Loss: 0.007736
# Epoch 611/1000 — Loss: 0.007754
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 612/1000 — Loss: 0.007756
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 613/1000 — Loss: 0.007738
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 614/1000 — Loss: 0.007744
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 615/1000 — Loss: 0.007742
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 616/1000 — Loss: 0.007732
# Epoch 617/1000 — Loss: 0.007735
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 618/1000 — Loss: 0.007741
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 619/1000 — Loss: 0.007735
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 620/1000 — Loss: 0.007743
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 621/1000 — Loss: 0.007744
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 622/1000 — Loss: 0.007729
# Epoch 623/1000 — Loss: 0.007734
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 624/1000 — Loss: 0.007750
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 625/1000 — Loss: 0.007763
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 626/1000 — Loss: 0.007785
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 627/1000 — Loss: 0.007815
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 628/1000 — Loss: 0.007772
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 629/1000 — Loss: 0.007747
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 630/1000 — Loss: 0.007737
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 631/1000 — Loss: 0.007721
# Epoch 632/1000 — Loss: 0.007730
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 633/1000 — Loss: 0.007732
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 634/1000 — Loss: 0.007717
# Epoch 635/1000 — Loss: 0.007710
# Epoch 636/1000 — Loss: 0.007718
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 637/1000 — Loss: 0.007723
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 638/1000 — Loss: 0.007724
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 639/1000 — Loss: 0.007727
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 640/1000 — Loss: 0.007721
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 641/1000 — Loss: 0.007714
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 642/1000 — Loss: 0.007722
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 643/1000 — Loss: 0.007737
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 644/1000 — Loss: 0.007740
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 645/1000 — Loss: 0.007732
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 646/1000 — Loss: 0.007717
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 647/1000 — Loss: 0.007713
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 648/1000 — Loss: 0.007706
# Epoch 649/1000 — Loss: 0.007700
# Epoch 650/1000 — Loss: 0.007706
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 651/1000 — Loss: 0.007709
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 652/1000 — Loss: 0.007698
# Epoch 653/1000 — Loss: 0.007688
# Epoch 654/1000 — Loss: 0.007695
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 655/1000 — Loss: 0.007709
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 656/1000 — Loss: 0.007717
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 657/1000 — Loss: 0.007722
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 658/1000 — Loss: 0.007727
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 659/1000 — Loss: 0.007739
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 660/1000 — Loss: 0.007777
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 661/1000 — Loss: 0.007794
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 662/1000 — Loss: 0.007828
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 663/1000 — Loss: 0.007775
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 664/1000 — Loss: 0.007726
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 665/1000 — Loss: 0.007702
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 666/1000 — Loss: 0.007719
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 667/1000 — Loss: 0.007755
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 668/1000 — Loss: 0.007748
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 669/1000 — Loss: 0.007733
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 670/1000 — Loss: 0.007710
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 671/1000 — Loss: 0.007701
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 672/1000 — Loss: 0.007712
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 673/1000 — Loss: 0.007721
#   ↳ nessun miglioramento per 20/1000 epoche
# Epoch 674/1000 — Loss: 0.007727
#   ↳ nessun miglioramento per 21/1000 epoche
# Epoch 675/1000 — Loss: 0.007708
#   ↳ nessun miglioramento per 22/1000 epoche
# Epoch 676/1000 — Loss: 0.007707
#   ↳ nessun miglioramento per 23/1000 epoche
# Epoch 677/1000 — Loss: 0.007727
#   ↳ nessun miglioramento per 24/1000 epoche
# Epoch 678/1000 — Loss: 0.007734
#   ↳ nessun miglioramento per 25/1000 epoche
# Epoch 679/1000 — Loss: 0.007715
#   ↳ nessun miglioramento per 26/1000 epoche
# Epoch 680/1000 — Loss: 0.007704
#   ↳ nessun miglioramento per 27/1000 epoche
# Epoch 681/1000 — Loss: 0.007712
#   ↳ nessun miglioramento per 28/1000 epoche
# Epoch 682/1000 — Loss: 0.007734
#   ↳ nessun miglioramento per 29/1000 epoche
# Epoch 683/1000 — Loss: 0.007721
#   ↳ nessun miglioramento per 30/1000 epoche
# Epoch 684/1000 — Loss: 0.007713
#   ↳ nessun miglioramento per 31/1000 epoche
# Epoch 685/1000 — Loss: 0.007702
#   ↳ nessun miglioramento per 32/1000 epoche
# Epoch 686/1000 — Loss: 0.007693
#   ↳ nessun miglioramento per 33/1000 epoche
# Epoch 687/1000 — Loss: 0.007683
# Epoch 688/1000 — Loss: 0.007677
# Epoch 689/1000 — Loss: 0.007683
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 690/1000 — Loss: 0.007685
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 691/1000 — Loss: 0.007681
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 692/1000 — Loss: 0.007684
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 693/1000 — Loss: 0.007687
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 694/1000 — Loss: 0.007687
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 695/1000 — Loss: 0.007691
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 696/1000 — Loss: 0.007692
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 697/1000 — Loss: 0.007685
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 698/1000 — Loss: 0.007676
# Epoch 699/1000 — Loss: 0.007674
# Epoch 700/1000 — Loss: 0.007681
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 701/1000 — Loss: 0.007686
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 702/1000 — Loss: 0.007690
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 703/1000 — Loss: 0.007686
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 704/1000 — Loss: 0.007689
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 705/1000 — Loss: 0.007690
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 706/1000 — Loss: 0.007698
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 707/1000 — Loss: 0.007694
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 708/1000 — Loss: 0.007698
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 709/1000 — Loss: 0.007690
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 710/1000 — Loss: 0.007680
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 711/1000 — Loss: 0.007672
# Epoch 712/1000 — Loss: 0.007668
# Epoch 713/1000 — Loss: 0.007668
# Epoch 714/1000 — Loss: 0.007661
# Epoch 715/1000 — Loss: 0.007659
# Epoch 716/1000 — Loss: 0.007661
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 717/1000 — Loss: 0.007671
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 718/1000 — Loss: 0.007684
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 719/1000 — Loss: 0.007688
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 720/1000 — Loss: 0.007679
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 721/1000 — Loss: 0.007666
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 722/1000 — Loss: 0.007660
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 723/1000 — Loss: 0.007669
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 724/1000 — Loss: 0.007687
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 725/1000 — Loss: 0.007710
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 726/1000 — Loss: 0.007720
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 727/1000 — Loss: 0.007718
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 728/1000 — Loss: 0.007704
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 729/1000 — Loss: 0.007677
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 730/1000 — Loss: 0.007654
# Epoch 731/1000 — Loss: 0.007644
# Epoch 732/1000 — Loss: 0.007651
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 733/1000 — Loss: 0.007660
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 734/1000 — Loss: 0.007662
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 735/1000 — Loss: 0.007659
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 736/1000 — Loss: 0.007659
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 737/1000 — Loss: 0.007661
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 738/1000 — Loss: 0.007661
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 739/1000 — Loss: 0.007656
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 740/1000 — Loss: 0.007650
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 741/1000 — Loss: 0.007645
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 742/1000 — Loss: 0.007650
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 743/1000 — Loss: 0.007654
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 744/1000 — Loss: 0.007654
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 745/1000 — Loss: 0.007648
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 746/1000 — Loss: 0.007640
# Epoch 747/1000 — Loss: 0.007637
# Epoch 748/1000 — Loss: 0.007642
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 749/1000 — Loss: 0.007646
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 750/1000 — Loss: 0.007643
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 751/1000 — Loss: 0.007638
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 752/1000 — Loss: 0.007640
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 753/1000 — Loss: 0.007653
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 754/1000 — Loss: 0.007657
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 755/1000 — Loss: 0.007660
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 756/1000 — Loss: 0.007666
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 757/1000 — Loss: 0.007669
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 758/1000 — Loss: 0.007664
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 759/1000 — Loss: 0.007655
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 760/1000 — Loss: 0.007657
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 761/1000 — Loss: 0.007674
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 762/1000 — Loss: 0.007712
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 763/1000 — Loss: 0.007723
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 764/1000 — Loss: 0.007742
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 765/1000 — Loss: 0.007697
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 766/1000 — Loss: 0.007686
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 767/1000 — Loss: 0.007695
#   ↳ nessun miglioramento per 20/1000 epoche
# Epoch 768/1000 — Loss: 0.007688
#   ↳ nessun miglioramento per 21/1000 epoche
# Epoch 769/1000 — Loss: 0.007685
#   ↳ nessun miglioramento per 22/1000 epoche
# Epoch 770/1000 — Loss: 0.007653
#   ↳ nessun miglioramento per 23/1000 epoche
# Epoch 771/1000 — Loss: 0.007649
#   ↳ nessun miglioramento per 24/1000 epoche
# Epoch 772/1000 — Loss: 0.007666
#   ↳ nessun miglioramento per 25/1000 epoche
# Epoch 773/1000 — Loss: 0.007663
#   ↳ nessun miglioramento per 26/1000 epoche
# Epoch 774/1000 — Loss: 0.007660
#   ↳ nessun miglioramento per 27/1000 epoche
# Epoch 775/1000 — Loss: 0.007654
#   ↳ nessun miglioramento per 28/1000 epoche
# Epoch 776/1000 — Loss: 0.007646
#   ↳ nessun miglioramento per 29/1000 epoche
# Epoch 777/1000 — Loss: 0.007653
#   ↳ nessun miglioramento per 30/1000 epoche
# Epoch 778/1000 — Loss: 0.007656
#   ↳ nessun miglioramento per 31/1000 epoche
# Epoch 779/1000 — Loss: 0.007655
#   ↳ nessun miglioramento per 32/1000 epoche
# Epoch 780/1000 — Loss: 0.007652
#   ↳ nessun miglioramento per 33/1000 epoche
# Epoch 781/1000 — Loss: 0.007642
#   ↳ nessun miglioramento per 34/1000 epoche
# Epoch 782/1000 — Loss: 0.007649
#   ↳ nessun miglioramento per 35/1000 epoche
# Epoch 783/1000 — Loss: 0.007663
#   ↳ nessun miglioramento per 36/1000 epoche
# Epoch 784/1000 — Loss: 0.007675
#   ↳ nessun miglioramento per 37/1000 epoche
# Epoch 785/1000 — Loss: 0.007680
#   ↳ nessun miglioramento per 38/1000 epoche
# Epoch 786/1000 — Loss: 0.007684
#   ↳ nessun miglioramento per 39/1000 epoche
# Epoch 787/1000 — Loss: 0.007678
#   ↳ nessun miglioramento per 40/1000 epoche
# Epoch 788/1000 — Loss: 0.007660
#   ↳ nessun miglioramento per 41/1000 epoche
# Epoch 789/1000 — Loss: 0.007656
#   ↳ nessun miglioramento per 42/1000 epoche
# Epoch 790/1000 — Loss: 0.007634
# Epoch 791/1000 — Loss: 0.007629
# Epoch 792/1000 — Loss: 0.007640
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 793/1000 — Loss: 0.007642
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 794/1000 — Loss: 0.007629
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 795/1000 — Loss: 0.007627
# Epoch 796/1000 — Loss: 0.007627
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 797/1000 — Loss: 0.007623
# Epoch 798/1000 — Loss: 0.007621
# Epoch 799/1000 — Loss: 0.007621
# Epoch 800/1000 — Loss: 0.007620
# Epoch 801/1000 — Loss: 0.007618
# Epoch 802/1000 — Loss: 0.007622
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 803/1000 — Loss: 0.007625
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 804/1000 — Loss: 0.007627
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 805/1000 — Loss: 0.007627
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 806/1000 — Loss: 0.007635
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 807/1000 — Loss: 0.007634
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 808/1000 — Loss: 0.007632
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 809/1000 — Loss: 0.007628
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 810/1000 — Loss: 0.007620
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 811/1000 — Loss: 0.007614
# Epoch 812/1000 — Loss: 0.007618
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 813/1000 — Loss: 0.007627
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 814/1000 — Loss: 0.007632
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 815/1000 — Loss: 0.007633
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 816/1000 — Loss: 0.007634
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 817/1000 — Loss: 0.007628
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 818/1000 — Loss: 0.007630
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 819/1000 — Loss: 0.007636
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 820/1000 — Loss: 0.007642
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 821/1000 — Loss: 0.007652
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 822/1000 — Loss: 0.007661
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 823/1000 — Loss: 0.007667
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 824/1000 — Loss: 0.007650
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 825/1000 — Loss: 0.007631
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 826/1000 — Loss: 0.007626
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 827/1000 — Loss: 0.007625
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 828/1000 — Loss: 0.007611
# Epoch 829/1000 — Loss: 0.007609
# Epoch 830/1000 — Loss: 0.007619
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 831/1000 — Loss: 0.007638
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 832/1000 — Loss: 0.007644
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 833/1000 — Loss: 0.007653
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 834/1000 — Loss: 0.007637
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 835/1000 — Loss: 0.007622
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 836/1000 — Loss: 0.007610
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 837/1000 — Loss: 0.007608
# Epoch 838/1000 — Loss: 0.007613
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 839/1000 — Loss: 0.007609
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 840/1000 — Loss: 0.007606
# Epoch 841/1000 — Loss: 0.007611
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 842/1000 — Loss: 0.007626
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 843/1000 — Loss: 0.007631
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 844/1000 — Loss: 0.007629
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 845/1000 — Loss: 0.007631
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 846/1000 — Loss: 0.007642
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 847/1000 — Loss: 0.007645
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 848/1000 — Loss: 0.007639
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 849/1000 — Loss: 0.007642
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 850/1000 — Loss: 0.007647
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 851/1000 — Loss: 0.007651
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 852/1000 — Loss: 0.007629
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 853/1000 — Loss: 0.007618
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 854/1000 — Loss: 0.007616
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 855/1000 — Loss: 0.007615
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 856/1000 — Loss: 0.007609
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 857/1000 — Loss: 0.007600
# Epoch 858/1000 — Loss: 0.007605
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 859/1000 — Loss: 0.007612
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 860/1000 — Loss: 0.007608
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 861/1000 — Loss: 0.007599
# Epoch 862/1000 — Loss: 0.007591
# Epoch 863/1000 — Loss: 0.007591
# Epoch 864/1000 — Loss: 0.007593
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 865/1000 — Loss: 0.007596
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 866/1000 — Loss: 0.007602
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 867/1000 — Loss: 0.007611
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 868/1000 — Loss: 0.007633
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 869/1000 — Loss: 0.007645
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 870/1000 — Loss: 0.007645
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 871/1000 — Loss: 0.007624
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 872/1000 — Loss: 0.007610
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 873/1000 — Loss: 0.007602
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 874/1000 — Loss: 0.007603
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 875/1000 — Loss: 0.007604
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 876/1000 — Loss: 0.007602
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 877/1000 — Loss: 0.007593
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 878/1000 — Loss: 0.007590
# Epoch 879/1000 — Loss: 0.007591
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 880/1000 — Loss: 0.007596
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 881/1000 — Loss: 0.007599
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 882/1000 — Loss: 0.007595
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 883/1000 — Loss: 0.007586
# Epoch 884/1000 — Loss: 0.007587
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 885/1000 — Loss: 0.007592
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 886/1000 — Loss: 0.007592
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 887/1000 — Loss: 0.007589
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 888/1000 — Loss: 0.007586
# Epoch 889/1000 — Loss: 0.007586
# Epoch 890/1000 — Loss: 0.007587
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 891/1000 — Loss: 0.007593
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 892/1000 — Loss: 0.007597
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 893/1000 — Loss: 0.007593
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 894/1000 — Loss: 0.007588
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 895/1000 — Loss: 0.007583
# Epoch 896/1000 — Loss: 0.007578
# Epoch 897/1000 — Loss: 0.007575
# Epoch 898/1000 — Loss: 0.007573
# Epoch 899/1000 — Loss: 0.007574
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 900/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 901/1000 — Loss: 0.007578
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 902/1000 — Loss: 0.007583
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 903/1000 — Loss: 0.007590
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 904/1000 — Loss: 0.007604
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 905/1000 — Loss: 0.007617
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 906/1000 — Loss: 0.007629
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 907/1000 — Loss: 0.007626
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 908/1000 — Loss: 0.007620
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 909/1000 — Loss: 0.007614
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 910/1000 — Loss: 0.007635
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 911/1000 — Loss: 0.007616
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 912/1000 — Loss: 0.007619
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 913/1000 — Loss: 0.007620
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 914/1000 — Loss: 0.007613
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 915/1000 — Loss: 0.007604
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 916/1000 — Loss: 0.007594
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 917/1000 — Loss: 0.007596
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 918/1000 — Loss: 0.007599
#   ↳ nessun miglioramento per 20/1000 epoche
# Epoch 919/1000 — Loss: 0.007597
#   ↳ nessun miglioramento per 21/1000 epoche
# Epoch 920/1000 — Loss: 0.007582
#   ↳ nessun miglioramento per 22/1000 epoche
# Epoch 921/1000 — Loss: 0.007574
#   ↳ nessun miglioramento per 23/1000 epoche
# Epoch 922/1000 — Loss: 0.007578
#   ↳ nessun miglioramento per 24/1000 epoche
# Epoch 923/1000 — Loss: 0.007582
#   ↳ nessun miglioramento per 25/1000 epoche
# Epoch 924/1000 — Loss: 0.007578
#   ↳ nessun miglioramento per 26/1000 epoche
# Epoch 925/1000 — Loss: 0.007572
# Epoch 926/1000 — Loss: 0.007575
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 927/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 928/1000 — Loss: 0.007577
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 929/1000 — Loss: 0.007577
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 930/1000 — Loss: 0.007579
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 931/1000 — Loss: 0.007587
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 932/1000 — Loss: 0.007592
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 933/1000 — Loss: 0.007608
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 934/1000 — Loss: 0.007629
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 935/1000 — Loss: 0.007650
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 936/1000 — Loss: 0.007630
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 937/1000 — Loss: 0.007614
#   ↳ nessun miglioramento per 12/1000 epoche
# Epoch 938/1000 — Loss: 0.007583
#   ↳ nessun miglioramento per 13/1000 epoche
# Epoch 939/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 14/1000 epoche
# Epoch 940/1000 — Loss: 0.007587
#   ↳ nessun miglioramento per 15/1000 epoche
# Epoch 941/1000 — Loss: 0.007597
#   ↳ nessun miglioramento per 16/1000 epoche
# Epoch 942/1000 — Loss: 0.007611
#   ↳ nessun miglioramento per 17/1000 epoche
# Epoch 943/1000 — Loss: 0.007614
#   ↳ nessun miglioramento per 18/1000 epoche
# Epoch 944/1000 — Loss: 0.007601
#   ↳ nessun miglioramento per 19/1000 epoche
# Epoch 945/1000 — Loss: 0.007582
#   ↳ nessun miglioramento per 20/1000 epoche
# Epoch 946/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 21/1000 epoche
# Epoch 947/1000 — Loss: 0.007575
#   ↳ nessun miglioramento per 22/1000 epoche
# Epoch 948/1000 — Loss: 0.007577
#   ↳ nessun miglioramento per 23/1000 epoche
# Epoch 949/1000 — Loss: 0.007578
#   ↳ nessun miglioramento per 24/1000 epoche
# Epoch 950/1000 — Loss: 0.007574
#   ↳ nessun miglioramento per 25/1000 epoche
# Epoch 951/1000 — Loss: 0.007573
#   ↳ nessun miglioramento per 26/1000 epoche
# Epoch 952/1000 — Loss: 0.007569
# Epoch 953/1000 — Loss: 0.007566
# Epoch 954/1000 — Loss: 0.007567
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 955/1000 — Loss: 0.007568
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 956/1000 — Loss: 0.007577
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 957/1000 — Loss: 0.007581
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 958/1000 — Loss: 0.007582
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 959/1000 — Loss: 0.007568
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 960/1000 — Loss: 0.007563
# Epoch 961/1000 — Loss: 0.007569
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 962/1000 — Loss: 0.007572
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 963/1000 — Loss: 0.007571
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 964/1000 — Loss: 0.007573
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 965/1000 — Loss: 0.007588
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 966/1000 — Loss: 0.007604
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 967/1000 — Loss: 0.007612
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 968/1000 — Loss: 0.007591
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 969/1000 — Loss: 0.007565
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 970/1000 — Loss: 0.007559
# Epoch 971/1000 — Loss: 0.007565
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 972/1000 — Loss: 0.007572
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 973/1000 — Loss: 0.007568
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 974/1000 — Loss: 0.007575
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 975/1000 — Loss: 0.007588
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 976/1000 — Loss: 0.007592
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 977/1000 — Loss: 0.007585
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 978/1000 — Loss: 0.007577
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 979/1000 — Loss: 0.007564
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 980/1000 — Loss: 0.007558
# Epoch 981/1000 — Loss: 0.007562
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 982/1000 — Loss: 0.007569
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 983/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 984/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 985/1000 — Loss: 0.007576
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 986/1000 — Loss: 0.007581
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 987/1000 — Loss: 0.007580
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 988/1000 — Loss: 0.007584
#   ↳ nessun miglioramento per 8/1000 epoche
# Epoch 989/1000 — Loss: 0.007579
#   ↳ nessun miglioramento per 9/1000 epoche
# Epoch 990/1000 — Loss: 0.007570
#   ↳ nessun miglioramento per 10/1000 epoche
# Epoch 991/1000 — Loss: 0.007560
#   ↳ nessun miglioramento per 11/1000 epoche
# Epoch 992/1000 — Loss: 0.007558
# Epoch 993/1000 — Loss: 0.007563
#   ↳ nessun miglioramento per 1/1000 epoche
# Epoch 994/1000 — Loss: 0.007573
#   ↳ nessun miglioramento per 2/1000 epoche
# Epoch 995/1000 — Loss: 0.007578
#   ↳ nessun miglioramento per 3/1000 epoche
# Epoch 996/1000 — Loss: 0.007575
#   ↳ nessun miglioramento per 4/1000 epoche
# Epoch 997/1000 — Loss: 0.007570
#   ↳ nessun miglioramento per 5/1000 epoche
# Epoch 998/1000 — Loss: 0.007566
#   ↳ nessun miglioramento per 6/1000 epoche
# Epoch 999/1000 — Loss: 0.007561
#   ↳ nessun miglioramento per 7/1000 epoche
# Epoch 1000/1000 — Loss: 0.007561
#   ↳ nessun miglioramento per 8/1000 epoche
# Training complete.

# %%
import time
import numpy as np
import torch

model.eval()

# take one representative batch
batch = next(iter(dataloader))
x   = batch["patch"].to(device, non_blocking=True)
vca = batch["vca"].to(device, non_blocking=True)
gt  = batch["gt"].to(device, non_blocking=True)

# optional: if using DataParallel, underlying model is still fine through model(...)
# no change needed

# -----------------------------
# 1) Warm-up
# -----------------------------
with torch.no_grad():
    for _ in range(20):
        #_ = model(x, vca, gt)
        _ = model(x, vca, gt, return_full=True)

torch.cuda.synchronize()

# -----------------------------
# 2) Measure inference latency
# -----------------------------
n_runs = 100
latencies = []

torch.cuda.reset_peak_memory_stats(device)

with torch.no_grad():
    for _ in range(n_runs):
        start = time.perf_counter()
        #_ = model(x, vca, gt)
        _ = model(x, vca, gt, return_full=True)
        torch.cuda.synchronize()
        end = time.perf_counter()
        latencies.append(end - start)

avg_latency_s = float(np.mean(latencies))
std_latency_s = float(np.std(latencies))
fps = 1.0 / avg_latency_s
peak_inference_mem_gb = torch.cuda.max_memory_allocated(device) / (1024**3)

print(f"Average inference latency: {avg_latency_s*1000:.3f} ms/image")
print(f"Latency std: {std_latency_s*1000:.3f} ms")
print(f"FPS: {fps:.3f}")
print(f"Peak inference memory: {peak_inference_mem_gb:.3f} GB")
# Out:
# Average inference latency: 2.451 ms/image
# Latency std: 0.011 ms
# FPS: 408.035
# Peak inference memory: 0.054 GB

# %%
def visualize_abundances_with_patch(abundances, patches, patch_ids=None, band=12, figsize_per=3):
    """
    Visualizza un batch di abundance maps disposte in due righe:
      - riga 0: il patch nella banda specificata (nel primo subplot)
      - riga 1: le E abundance maps (una per endmember)

    Parameters:
        abundances (torch.Tensor): [B, E, H, W] output del modello.
        patches    (torch.Tensor): [B, bands, H, W] input originale.
        patch_ids  (list[int], optional): identificativi delle patch.
        band       (int): indice della banda da mostrare, default 12.
        figsize_per(float): dimensione di ciascun subplot in pollici.
    """
    import matplotlib.pyplot as plt

    abund_np = abundances.detach().cpu().numpy()
    patch_np  = patches.detach().cpu().numpy()
    B, E, H, W = abund_np.shape

    for i in range(B):
        fig, axes = plt.subplots(2, E, 
                                 figsize=(figsize_per * E, figsize_per * 2),
                                 squeeze=False)
        # --- prima riga: patch (band 'band') in axes[0,0], gli altri a vuoto
        ax0 = axes[0, 0]
        im0 = ax0.imshow(patch_np[i, band], cmap='gray')
        title = f'Patch {patch_ids[i]}' if patch_ids else f'Sample {i}'
        ax0.set_title(f'{title}\nBand {band}')
        ax0.axis('off')
        fig.colorbar(im0, ax=ax0, fraction=0.046, pad=0.04)

        # nascondi eventuali subplot vuoti in prima riga
        for j in range(1, E):
            axes[0, j].axis('off')

        # --- seconda riga: le E abundance maps
        for e in range(E):
            ax = axes[1, e]
            im = ax.imshow(abund_np[i, e], cmap='jet', vmin=0, vmax=1)
            ax.set_title(f'EM {e}')
            ax.axis('off')
            fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

        plt.tight_layout()
        plt.show()

# %%
# prendi un batch
batch = next(iter(dataloader))
x          = batch['patch']        # [B, bands, H, W]
#abundances = model(x.cuda(), batch['vca'].cuda(), batch['gt'].cuda())
abundances = model(x.cuda(), batch['vca'].cuda(), batch['gt'].cuda(),return_full=True)
patch_ids  = batch['patch_number'] # lista di interi

visualize_abundances_with_patch(
    abundances,
    x,
    patch_ids=patch_ids,
    band=12,
    figsize_per=5
)

# %%
ab_np = abundances[0].detach().cpu().numpy()   # → (E, H, W)
ab_np.shape
np.save('ViT_jasper_abundances_b01_P4.npy', ab_np)

# %%
from sklearn.metrics import mean_squared_error

def spectral_angle(a, b):
    """SAD in radians between two 1D NumPy arrays."""
    cos = np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12)
    cos = np.clip(cos, -1, 1)
    return np.arccos(cos)

def weighted_median(data, weights):
    """
    Compute the weighted median of 1D `data` with positive `weights`.
    """
    # sort data and weights by data value
    idx = np.argsort(data)
    d = data[idx]
    w = weights[idx]
    cum = np.cumsum(w)
    cutoff = w.sum() / 2.0
    return d[np.searchsorted(cum, cutoff)]

# 1) Fetch one patch, its abundances, and the GT spectra
batch  = next(iter(dataloader))
x_t    = batch['patch'][0].cpu()       # [bands, H, W]
abund_t= (model(batch['patch'].cuda(),
                batch['vca'].cuda(),
                batch['gt'].cuda())
           .detach()
           .cpu()[0])                   # [E, h', w']
spec_gt= batch['gt'][0].cpu()          # [E, bands]

# 2) Convert to NumPy and check shapes
fm1 = abundances.detach().cpu()[0]
x_np     = x_t.numpy()                 # [bands, H, W]
abund_np = fm1.numpy()             # [E, h', w']
gt_np    = spec_gt.numpy()             # [E, bands]

bands, H, W = x_np.shape
E,  h2, w2  = abund_np.shape

lower_thresh = 0.85
upper_thresh =1
E =4
rec_specs = []
for e in range(E):
    a = fm1[e]   # [h', w'] abundance map for endmember e
    # keep only pixels with lower_thresh < a < upper_thresh
    mask = (a > lower_thresh) & (a < upper_thresh)  

    if mask.sum() == 0:
        rec_specs.append(torch.zeros(bands, device=x_t.device))
        continue

    selected = x_t[:, mask]           # [bands, N_pixels]
    med = selected.median(dim=1).values  # [bands]
    rec_specs.append(med)

rec_specs = torch.stack(rec_specs)      # [E, bands]
perm = [3, 1, 2, 0]
rec_specs = rec_specs[perm]
# 5) Plot GT vs. Rec with RMSE & SAD
cols      = 4
rows      = int(np.ceil(E / cols))
fig, axes = plt.subplots(rows, cols, figsize=(20, 5), sharex=True, sharey=True)
axes      = axes.flatten()
x_axis    = np.arange(bands)

for i in range(E):
    ax   = axes[i]
    sns.lineplot(x=x_axis, y=gt_np[i],  ax=ax, label='GT', marker='o')
    sns.lineplot(x=x_axis, y=rec_specs[i], ax=ax, label='Rec', linestyle='--')
    rmse = np.sqrt(mean_squared_error(gt_np[i], rec_specs[i]))
    sad  = spectral_angle(gt_np[i], rec_specs[i])
    ax.set_title(f'EM {i} | RMSE={rmse:.3f} | SAD={sad:.3f} rad')
    ax.set_xlabel('Band')
    ax.set_ylabel('Intensity')
    ax.legend()
    ax.grid(True)

# remove unused axes
for j in range(E, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3267015/2787655211.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   cos = np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12)
# /tmp/ipykernel_3267015/2787655211.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   cos = np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12)
# /tmp/ipykernel_3267015/2787655211.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   cos = np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12)
# /tmp/ipykernel_3267015/2787655211.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   cos = np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12)

# %%
def spectral_angle(a, b):
    """SAD in radians between two 1D NumPy arrays."""
    cos_val = np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b) + 1e-12)
    cos_val = np.clip(cos_val, -1, 1)
    return np.arccos(cos_val)

# 1) Fetch one batch
batch = next(iter(dataloader))
x_t = batch['patch'][0].cpu()    # [bands, H, W]
abund_tensor = (model(batch['patch'].cuda(),
                       batch['vca'].cuda(),
                       batch['gt'].cuda(),return_full=True)
                .detach()
                .cpu()[0])      # [E, h', w']
spec_gt = batch['gt'][0].cpu()    # [E, bands]

# 2) Convert to NumPy
x_np = x_t.numpy()                       # [bands, H, W]
abund_np = abund_tensor.numpy()          # [E, h', w']
gt_np = spec_gt.numpy()                  # [E, bands]

bands, H, W = x_np.shape
E = gt_np.shape[0]

# 3) Reconstruct spectra via median on high-abundance pixels
lower_thresh = 0.85
upper_thresh = 1.0
rec_specs = []

for e in range(E):
    a_map = abund_tensor[e]  # tensor [h', w']
    mask = (a_map > lower_thresh) & (a_map < upper_thresh)
    if mask.sum() == 0:
        rec_specs.append(np.zeros(bands))
        continue
    # select pixel spectra: shape [bands, N_pixels]
    selected = x_t[:, mask.numpy()]
    # median along pixels
    med = selected.median(dim=1).values.numpy()
    rec_specs.append(med)

rec_specs = np.stack(rec_specs, axis=0)  # [E, bands]

# 4) Undo L2-normalization by scaling with ground-truth norms
# compute GT endmember L2 norms

norms_gt = np.linalg.norm(gt_np, axis=1)  # (E,)
rec_specs_unnorm = rec_specs * norms_gt[:, None]  # [E, bands]
perm = [3, 1, 2, 0]
rec_specs_unnorm = rec_specs_unnorm[perm]
# 5) Plot GT vs. Reconstructed (unnormalized) with metrics
cols = 4
rows = int(np.ceil(E / cols))
fig, axes = plt.subplots(rows, cols, figsize=(20, 5), sharex=True, sharey=True)
axes = axes.flatten()
x_axis = np.arange(1, bands + 1)

for i in range(E):
    ax = axes[i]
    sns.lineplot(x=x_axis, y=gt_np[i], ax=ax, label='Ground truth', marker='o')
    sns.lineplot(x=x_axis, y=rec_specs_unnorm[i], ax=ax, label='Estimated', linestyle='--')
    rmse = np.sqrt(mean_squared_error(gt_np[i], rec_specs_unnorm[i]))
    sad = spectral_angle(gt_np[i], rec_specs_unnorm[i])
    ax.set_title(f'EM {i}: RMSE={rmse:.3f}, SAD={sad:.3f} rad')
    ax.set_xlabel('Band')
    ax.set_ylabel('Intensity')
    ax.legend()
    ax.grid(False)

# remove unused axes
for j in range(E, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# /home/scillad/miniconda3/envs/unmixing/lib/python3.10/site-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
np.save('ViT_Endmembers_JASPER_b01_P4.npy', rec_specs_unnorm)
